# %% [markdown]
# # K-Means Clustering

# %%
#import libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# importing the dataset
data = pd.read_csv('Mall_Customers.csv')

# %%
# 
X = data.iloc[: , [3,4]].values

# %%
data.shape
# Out:
# (200, 5)

# %%
# using the elbow method to finmd the number of clusters
from sklearn.cluster import KMeans
wcss = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters = i, 
                    init = 'k-means++', 
                    max_iter = 300,
                    n_init = 10,
                    random_state = 0)
    kmeans.fit(X)
    wcss.append(kmeans.inertia_)
plt.plot(range(1,11),wcss)
plt.title('The Elbow Method')
plt.xlabel('Number of Clusters')
plt.ylabel('WCSS')
plt.show()

# %%
# Applying K-Means to the data set

kmeans = KMeans(n_clusters = 5,
               init = 'k-means++',
               max_iter = 300,
               n_init = 10,
               random_state = 0,
               verbose=5)
y_kmeans = kmeans.fit_predict(X)
# Out:
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 48479.3291485813
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 44448.45544793371
# start iteration
# done sorting
# end inner loop
# Iteration 2, inertia 44448.45544793371
# center shift 0.000000e+00 within tolerance 6.749532e-02
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 68462.8208874459
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 66790.25561457992
# start iteration
# done sorting
# end inner loop
# Iteration 2, inertia 66790.25561457992
# center shift 0.000000e+00 within tolerance 6.749532e-02
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 49222.2819411583
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 44698.647977090004
# start iteration
# done sorting
# end inner loop
# Iteration 2, inertia 44489.3318656652
# start iteration
# done sorting
# end inner loop
# Iteration 3, inertia 44454.47647967974
# start iteration
# done sorting
# end inner loop
# Iteration 4, inertia 44454.47647967974
# center shift 0.000000e+00 within tolerance 6.749532e-02
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 45743.31673265006
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 44576.264138706174
# start iteration
# done sorting
# end inner loop
# Iteration 2, inertia 44448.45544793371
# start iteration
# done sorting
# end inner loop
# Iteration 3, inertia 44448.45544793371
# center shift 0.000000e+00 within tolerance 6.749532e-02
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 61257.61224387486
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 55816.51150932402
# start iteration
# done sorting
# end inner loop
# Iteration 2, inertia 50906.44687057459
# start iteration
# done sorting
# end inner loop
# Iteration 3, inertia 46018.09115119984
# start iteration
# done sorting
# end inner loop
# Iteration 4, inertia 44448.45544793371
# start iteration
# done sorting
# end inner loop
# Iteration 5, inertia 44448.45544793371
# center shift 0.000000e+00 within tolerance 6.749532e-02
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 68095.43786822933
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 66733.43857149451
# start iteration
# done sorting
# end inner loop
# Iteration 2, inertia 66733.43857149451
# center shift 0.000000e+00 within tolerance 6.749532e-02
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 71027.73992673993
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 50713.64852152678
# start iteration
# done sorting
# end inner loop
# Iteration 2, inertia 45850.33813444797
# start iteration
# done sorting
# end inner loop
# Iteration 3, inertia 44537.16153049849
# start iteration
# done sorting
# end inner loop
# Iteration 4, inertia 44448.45544793371
# start iteration
# done sorting
# end inner loop
# Iteration 5, inertia 44448.45544793371
# center shift 0.000000e+00 within tolerance 6.749532e-02
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 45591.894592133714
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 44641.895981729314
# start iteration
# done sorting
# end inner loop
# Iteration 2, inertia 44454.47647967974
# start iteration
# done sorting
# end inner loop
# Iteration 3, inertia 44454.47647967974
# center shift 0.000000e+00 within tolerance 6.749532e-02
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 82650.72824074075
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 76689.6328655235
# start iteration
# done sorting
# end inner loop
# Iteration 2, inertia 75611.76489858843
# start iteration
# done sorting
# end inner loop
# Iteration 3, inertia 75499.87204668057
# start iteration
# done sorting
# end inner loop
# Iteration 4, inertia 75474.78085450782
# start iteration
# done sorting
# end inner loop
# Iteration 5, inertia 75447.86779068885
# start iteration
# done sorting
# end inner loop
# Iteration 6, inertia 75303.07943219572
# start iteration
# done sorting
# end inner loop
# Iteration 7, inertia 75030.09412719632
# start iteration
# done sorting
# end inner loop
# Iteration 8, inertia 74645.61638101988
# start iteration
# done sorting
# end inner loop
# Iteration 9, inertia 74126.75220458553
# start iteration
# done sorting
# end inner loop
# Iteration 10, inertia 72965.68650949758
# start iteration
# done sorting
# end inner loop
# Iteration 11, inertia 72233.06331569664
# start iteration
# done sorting
# end inner loop
# Iteration 12, inertia 71691.92161751544
# start iteration
# done sorting
# end inner loop
# Iteration 13, inertia 69067.1748463987
# start iteration
# done sorting
# end inner loop
# Iteration 14, inertia 59049.90084204414
# start iteration
# done sorting
# end inner loop
# Iteration 15, inertia 44454.47647967974
# start iteration
# done sorting
# end inner loop
# Iteration 16, inertia 44454.47647967974
# center shift 0.000000e+00 within tolerance 6.749532e-02
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 48279.9377929014
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 44650.90790627557
# start iteration
# done sorting
# end inner loop
# Iteration 2, inertia 44454.47647967974
# start iteration
# done sorting
# end inner loop
# Iteration 3, inertia 44454.47647967974
# center shift 0.000000e+00 within tolerance 6.749532e-02

# %%
# Visualizing the Clusters
plt.figure(figsize=(20,10))
plt.scatter(X[y_kmeans == 0 , 0], X[y_kmeans == 0, 1], s = 100, c= 'red', label = 'Careful')
plt.scatter(X[y_kmeans == 1 , 0], X[y_kmeans == 1, 1], s = 100, c= 'blue', label = 'Standard')
plt.scatter(X[y_kmeans == 2 , 0], X[y_kmeans == 2, 1], s = 100, c= 'green', label = 'Target')
plt.scatter(X[y_kmeans == 3 , 0], X[y_kmeans == 3, 1], s = 100, c= 'magenta', label = 'Careless')
plt.scatter(X[y_kmeans == 4 , 0], X[y_kmeans == 4, 1], s = 100, c= 'cyan', label = 'Sensible')
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[: , 1], s= 300, c= 'yellow', label = 'Centroids')
plt.title('Clusters of Clients')
plt.xlabel('Annual Income k$')
plt.ylabel('Spending Score (1-100)')
plt.legend()
plt.show()
